# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # Visualization

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = df['Rings'], y = df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Diameter'>

# %%
sns.jointplot(x = df['Rings'], y = df['Shell weight'])

# %%
sns.barplot(x = df['Rings'], y = df['Length'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Length'>

# %%
sns.distplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
ranges = df.max() - df.min()
ranges
# Out:
# Sex                2.0000
# Length             0.7400
# Diameter           0.5950
# Height             1.1300
# Whole weight       2.8235
# Shucked weight     1.4870
# Viscera weight     0.7595
# Shell weight       1.0035
# Rings             28.0000
# dtype: float64

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
df.kurt()
# Out:
# Sex               -1.514387
# Length             0.064621
# Diameter          -0.045476
# Height            76.025509
# Whole weight      -0.023644
# Shucked weight     0.595124
# Viscera weight     0.084012
# Shell weight       0.531926
# Rings              2.330687
# dtype: float64

# %%
df.var()
# Out:
# Sex                0.676079
# Length             0.014422
# Diameter           0.009849
# Height             0.001750
# Whole weight       0.240481
# Shucked weight     0.049268
# Viscera weight     0.012015
# Shell weight       0.019377
# Rings             10.395266
# dtype: float64

# %%
df.std()
# Out:
# Sex               0.822240
# Length            0.120093
# Diameter          0.099240
# Height            0.041827
# Whole weight      0.490389
# Shucked weight    0.221963
# Viscera weight    0.109614
# Shell weight      0.139203
# Rings             3.224169
# dtype: float64

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %% [markdown]
# # Missing Values

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Handling Outliers

# %%
a = df.quantile(q=[0.75,0.25])
IQR = a.iloc[0] - a.iloc[1]
IQR
# Out:
# Sex               2.0000
# Length            0.1650
# Diameter          0.1300
# Height            0.0500
# Whole weight      0.7115
# Shucked weight    0.3160
# Viscera weight    0.1595
# Shell weight      0.1990
# Rings             3.0000
# dtype: float64

# %%
upper = a.iloc[0]+(1.5*IQR)
lower = a.iloc[0]-(1.5*IQR)

# %%
upper
# Out:
# Sex                5.00000
# Length             0.86250
# Diameter           0.67500
# Height             0.24000
# Whole weight       2.22025
# Shucked weight     0.97600
# Viscera weight     0.49225
# Shell weight       0.62750
# Rings             15.50000
# dtype: float64

# %%
lower
# Out:
# Sex              -1.00000
# Length            0.36750
# Diameter          0.28500
# Height            0.09000
# Whole weight      0.08575
# Shucked weight    0.02800
# Viscera weight    0.01375
# Shell weight      0.03050
# Rings             6.50000
# dtype: float64

# %%
df['Length'] = np.where(df['Length'] < 0.36750, df['Length'].mean(), df['Length'])
df['Length'] = np.where(df['Length'] > 0.86250, df['Length'].mean(), df['Length'])

# %%
sns.boxplot(df['Length'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Dependent and Independent Variable

# %%
x = df.drop(columns='Rings')
y = df['Rings']

# %%
x
# Out:
#       Sex    Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2  0.455000     0.365   0.095        0.5140          0.2245
# 1       2  0.523992     0.265   0.090        0.2255          0.0995
# 2       0  0.530000     0.420   0.135        0.6770          0.2565
# 3       2  0.440000     0.365   0.125        0.5160          0.2155
# 4       1  0.523992     0.255   0.080        0.2050          0.0895
# ...   ...       ...       ...     ...           ...             ...
# 4172    0  0.565000     0.450   0.165        0.8870          0.3700
# 4173    2  0.590000     0.440   0.135        0.9660          0.4390
# 4174    2  0.600000     0.475   0.205        1.1760          0.5255
# 4175    0  0.625000     0.485   0.150        1.0945          0.5310
# 4176    2  0.710000     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import scale
y = scale(y)
y
# Out:
# array([ 1.57154357, -0.91001299, -0.28962385, ..., -0.28962385,
#         0.02057072,  0.64095986])

# %% [markdown]
# # Splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# # MLR

# %%
from sklearn.linear_model import LinearRegression
MLR = LinearRegression()
MLR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = MLR.predict(x_test)
pred
# Out:
# array([ 1.00611155e+00, -5.71290980e-02,  1.56899299e-01, -1.47714817e+00,
#         2.73445848e-01,  5.35135947e-01, -5.90818072e-01,  3.79654912e-03,
#        -3.39361820e-01,  7.10201941e-01, -3.41069095e-01, -1.22695221e+00,
#        -4.71791079e-01, -2.58624637e-01, -1.42076893e+00, -1.94147354e-01,
#        -8.00670760e-01,  1.24937668e+00,  3.39956833e-01, -4.88386815e-01,
#        -5.52071791e-01, -9.74014182e-01, -1.25321414e-01, -9.32421640e-01,
#         7.33040252e-02,  4.40638461e-01, -1.73607444e+00,  1.00802686e+00,
#         2.03662566e-01,  4.75516587e-01, -4.64833126e-01, -1.76747635e+00,
#         3.50926982e-01,  9.78959368e-01, -6.69620128e-01, -4.85534259e-01,
#        -2.72243414e-01,  1.17163541e-03, -3.35912734e-01,  4.55089767e-01,
#         4.62086521e-01, -2.08333476e-01,  5.93562518e-01,  5.93848178e-01,
#         7.47232447e-01, -1.24021337e-01, -3.46946667e-01,  4.03019604e-01,
# ...

# %%
df
# Out:
#       Sex    Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2  0.455000     0.365   0.095        0.5140          0.2245
# 1       2  0.523992     0.265   0.090        0.2255          0.0995
# 2       0  0.530000     0.420   0.135        0.6770          0.2565
# 3       2  0.440000     0.365   0.125        0.5160          0.2155
# 4       1  0.523992     0.255   0.080        0.2050          0.0895
# ...   ...       ...       ...     ...           ...             ...
# 4172    0  0.565000     0.450   0.165        0.8870          0.3700
# 4173    2  0.590000     0.440   0.135        0.9660          0.4390
# 4174    2  0.600000     0.475   0.205        1.1760          0.5255
# 4175    0  0.625000     0.485   0.150        1.0945          0.5310
# 4176    2  0.710000     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
MLR.predict([[2,0.45, 0.36, 0.09, 0.51, 0.22, 0.101, 0.150]])
# Out:
# array([-0.23540915])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, MLR.predict(x_test))
# Out:
# 0.5320757278069201

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,MLR.predict(x_test)))
# Out:
# 0.6992671241981798
